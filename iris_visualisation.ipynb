# %%
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.datasets import load_iris
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = load_iris()

# %%
X=data.data
y=data.target

# %%
ydf=pd.DataFrame(y,columns=["class"])

# %%
xdf=pd.DataFrame(X,index=np.arange(0,150),columns=data.feature_names)

# %%
df=pd.concat([xdf,ydf],axis=1)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    class
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
df.columns = ['sepal_length', 'sepal_width',"petal_length","petal_width","class"]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  class
# 0           5.1          3.5           1.4          0.2      0
# 1           4.9          3.0           1.4          0.2      0
# 2           4.7          3.2           1.3          0.2      0
# 3           4.6          3.1           1.5          0.2      0
# 4           5.0          3.6           1.4          0.2      0

# %%
plt.scatter(df.index,df["sepal_width"])
plt.show()

# %%
sns.scatterplot(x=df.index,y=df["sepal_width"],hue=y)
plt.show()

# %%
df.groupby("class").mean()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# class
# 0             5.006        3.428         1.462        0.246
# 1             5.936        2.770         4.260        1.326
# 2             6.588        2.974         5.552        2.026

# %% [markdown]
# ### 3.  STRIP PLOT

# %%
sns.stripplot(y=df["sepal_width"])
plt.show()

# %%
sns.stripplot(y=df["sepal_width"],x=df["class"])
plt.show()

# %% [markdown]
# ### Swarm Plot

# %%
sns.swarmplot(x=df["sepal_width"])
plt.show()

# %%
sns.swarmplot(y=df["sepal_width"],x=df["class"])
plt.show()

# %% [markdown]
# ## Uni-variate summary plots :

# %% [markdown]
# ### HISTOGRAMS

# %%
plt.hist(df["petal_width"])
plt.show()

# %%
sns.distplot(df["petal_width"],kde=False,bins=10)
plt.show()
# Out:
# C:\Users\aligi\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Density Plot

# %%
plt.figure(figsize=(5,5))
df["petal_length"].plot(kind="density")
plt.show()

# %%
sns.set(rc={"figure.figsize":(5,5)})
sns.kdeplot(df["petal_length"],shade=True)
plt.show()

# %%
plt.violinplot(df.values,showmedians=True)
plt.show()

# %%
sns.violinplot(y=df["petal_width"],x=df["class"],orient="vertical")
plt.show()

# %% [markdown]
# ### BAR

# %%
df["class"].value_counts().plot.bar()
plt.show()

# %%
sns.countplot(df["class"])
plt.show()
# Out:
# C:\Users\aligi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Pie Chart

# %%
dfsample=df.sample(frac=0.75) #! verilerin yüzde 75ini rastgele bir şekilde aldık

# %%
plt.pie(dfsample["class"].value_counts(),labels=["Setosa","Versicolor","Virginica"],autopct="%.3f",shadow=True)
plt.show()

# %%
plt.plot(df.index,df["petal_length"],markevery=1,marker="d")
for name,group in df.groupby("class"):
    plt.plot(group.index,group["petal_length"],label=name,markevery=1,marker="d")
plt.legend()
plt.show()
